# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # AudioXplorer
# ### Predict song genre based on different song features
# - The data is downloaded from https://www.kaggle.com/datasets/nanditapore/spotify-track-features
# - The data is from Spotify - it is collected using the [Spotify Developer API](https://developer.spotify.com/documentation/web-api) and in fact the data is real

# %%
# Read the data from the csv file
song_features = pd.read_csv("data/song_track.csv")

# %%
song_features.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
song_features.describe().T
# Out:
#                      count           mean            std          min  \
# popularity        232725.0      41.127502      18.189948      0.00000
# acousticness      232725.0       0.368560       0.354768      0.00000
# danceability      232725.0       0.554364       0.185608      0.05690
# duration_ms       232725.0  235122.339306  118935.909299  15387.00000
# energy            232725.0       0.570958       0.263456      0.00002
# instrumentalness  232725.0       0.148301       0.302768      0.00000
# liveness          232725.0       0.215009       0.198273      0.00967
# loudness          232725.0      -9.569885       5.998204    -52.45700
# speechiness       232725.0       0.120765       0.185518      0.02220
# tempo             232725.0     117.666585      30.898907     30.37900
# valence           232725.0       0.454917       0.260065      0.00000
#
#                           25%            50%          75%          max
# ...

# %%
# trck_id is a uniqie identifier and it do not bring any infomration about the genre, so we can drop it from the dataset
song_features = song_features.drop("track_id", axis = 1)

# %%
song_features.shape
# Out:
# (232725, 17)

# %%
# let's see how the data is distributed by genre
song_features.groupby("genre").size()
# Out:
# genre
# A Capella            119
# Alternative         9263
# Anime               8936
# Blues               9023
# Children's Music    5403
# Children’s Music    9353
# Classical           9256
# Comedy              9681
# Country             8664
# Dance               8701
# Electronic          9377
# Folk                9299
# Hip-Hop             9295
# Indie               9543
# Jazz                9441
# Movie               7806
# Opera               8280
# Pop                 9386
# R&B                 8992
# Rap                 9232
# Reggae              8771
# Reggaeton           8927
# Rock                9272
# Ska                 8874
# Soul                9089
# Soundtrack          9646
# World               9096
# dtype: int64

# %%
# TODO: analyze the data (get to know with the data)

# %%
# TODO: clean some data if necessary

# %%
# TODO think how to normalize the data (MinMaxScaler, StandartScaler)

# %%
# TODO: think how to cope with the text data (artist_name, track_name)

# %%
# TODO think how to cope with categorical features like key and mode

# %%
# TODO split data for test and train

# %%
# TODO try different models and examine the score

# %%
# TODO try hyperparameter optimization (GridSearch)

# %%
# TODO try feature selection or dimensionality reduction if necessary

# %%
# TODO try some boosting methods of necessary
